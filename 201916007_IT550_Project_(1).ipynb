# %% [markdown]
# # To Identify Terrorist Events using Event Triggers

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Import Pre-defined Libraries/Packages/Modules/Methods

# %%
import pandas as pd
import numpy as np
import spacy as sp
import pickle
import os
from collections import OrderedDict
import string
import re
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.corpus import wordnet
# from nltk.stem import WordNetLemmatizer
# from nltk.stem import LancasterStemmer
from nltk.stem import PorterStemmer

# %% [markdown]
# ### Installations/Loading

# %%
# !python -m nltk.downloader wordnet
# Out:
# /usr/lib/python3.6/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !python -m spacy download en_core_web_lg
# !pip3 install spacy-wordnet
# Out:
# Requirement already satisfied: en_core_web_lg==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz#egg=en_core_web_lg==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (46.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.18.3)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.38.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.21.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')
# Requirement already satisfied: spacy-wordnet in /usr/local/lib/python3.6/dist-packages (0.0.4)
# Requirement already satisfied: nltk<3.4,>=3.3 in /usr/local/lib/python3.6/dist-packages (from spacy-wordnet) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk<3.4,>=3.3->spacy-wordnet) (1.12.0)

# %% [markdown]
# ### Import Custom Modules

# %% [markdown]
# ## Global Objects

# %%
nlp = sp.load('en_core_web_lg')

# %%
HOME_PATH = './drive/My Drive/Colab Notebooks/201916007_PROJECT_IT550'
DATABASES_PATH = HOME_PATH + '/DATABASES'
GTD = DATABASES_PATH + '/globalterrorismdb_0718dist.csv'
RDWTI = DATABASES_PATH + '/RAND_Database_of_Worldwide_Terrorism_Incidents.csv'
INTERMEDIATE_FILES_PATH = HOME_PATH + '/INTERMEDIATE_FILES'
FIRE_DATABASE_FILES_PATH = HOME_PATH + '/FIRE_DATABASE_FILES'
FIRE_DATA_DICT = FIRE_DATABASE_FILES_PATH + '/file_data_dict.txt'
TRIGGERS_PATH = HOME_PATH + '/TRIGGERS'
TERRORIST_EVENTS_UPDATED1_PATH = TRIGGERS_PATH+'/TERRORIST_EVENT_TRIGGERS_UPDATED1.txt'
ENCODING = 'ISO-8859-1'
ENGINE = 'python'
# LEM = WordNetLemmatizer()
# LANCASTER = LancasterStemmer()
PORTER = PorterStemmer()

# %% [markdown]
# ## Exploratory Data Analysis: GTD, RDWTI, FIRE-DATABASE

# %% [markdown]
# ### GTD (Global Terrorism Database)

# %% [markdown]
# #### Load database

# %%
gtd = pd.read_csv(GTD, engine=ENGINE, encoding=ENCODING)

# %% [markdown]
# #### EDA

# %%
print(gtd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB
# None

# %%
print(gtd.head())
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
print(gtd.columns.values)
# Out:
# ['eventid' 'iyear' 'imonth' 'iday' 'approxdate' 'extended' 'resolution'
#  'country' 'country_txt' 'region' 'region_txt' 'provstate' 'city'
#  'latitude' 'longitude' 'specificity' 'vicinity' 'location' 'summary'
#  'crit1' 'crit2' 'crit3' 'doubtterr' 'alternative' 'alternative_txt'
#  'multiple' 'success' 'suicide' 'attacktype1' 'attacktype1_txt'
#  'attacktype2' 'attacktype2_txt' 'attacktype3' 'attacktype3_txt'
#  'targtype1' 'targtype1_txt' 'targsubtype1' 'targsubtype1_txt' 'corp1'
#  'target1' 'natlty1' 'natlty1_txt' 'targtype2' 'targtype2_txt'
#  'targsubtype2' 'targsubtype2_txt' 'corp2' 'target2' 'natlty2'
#  'natlty2_txt' 'targtype3' 'targtype3_txt' 'targsubtype3'
#  'targsubtype3_txt' 'corp3' 'target3' 'natlty3' 'natlty3_txt' 'gname'
#  'gsubname' 'gname2' 'gsubname2' 'gname3' 'gsubname3' 'motive'
#  'guncertain1' 'guncertain2' 'guncertain3' 'individual' 'nperps'
#  'nperpcap' 'claimed' 'claimmode' 'claimmode_txt' 'claim2' 'claimmode2'
#  'claimmode2_txt' 'claim3' 'claimmode3' 'claimmode3_txt' 'compclaim'
#  'weaptype1' 'weaptype1_txt' 'weapsubtype1' 'weapsubtype1_txt' 'weaptype2'
#  'weaptype2_txt' 'weapsubtype2' 'weapsubtype2_txt' 'weaptype3'
#  'weaptype3_txt' 'weapsubtype3' 'weapsubtype3_txt' 'weaptype4'
#  'weaptype4_txt' 'weapsubtype4' 'weapsubtype4_txt' 'weapdetail' 'nkill'
#  'nkillus' 'nkillter' 'nwound' 'nwoundus' 'nwoundte' 'property'
#  'propextent' 'propextent_txt' 'propvalue' 'propcomment' 'ishostkid'
#  'nhostkid' 'nhostkidus' 'nhours' 'ndays' 'divert' 'kidhijcountry'
#  'ransom' 'ransomamt' 'ransomamtus' 'ransompaid' 'ransompaidus'
#  'ransomnote' 'hostkidoutcome' 'hostkidoutcome_txt' 'nreleased' 'addnotes'
#  'scite1' 'scite2' 'scite3' 'dbsource' 'INT_LOG' 'INT_IDEO' 'INT_MISC'
#  'INT_ANY' 'related']

# %%
i,j = 0,2
while j <= 135:
  print(gtd.iloc[-5:, i:j])
  i += 2
  j += 2
# Out:
#              eventid  iyear
# 181686  201712310022   2017
# 181687  201712310029   2017
# 181688  201712310030   2017
# 181689  201712310031   2017
# 181690  201712310032   2017
#         imonth  iday
# 181686      12    31
# 181687      12    31
# 181688      12    31
# 181689      12    31
# 181690      12    31
#        approxdate  extended
# 181686        NaN         0
# 181687        NaN         0
# 181688        NaN         0
# 181689        NaN         0
# 181690        NaN         0
#        resolution  country
# 181686        NaN      182
# 181687        NaN      200
# 181688        NaN      160
# 181689        NaN       92
# 181690        NaN      160
#         country_txt  region
# 181686      Somalia      11
# 181687        Syria      10
# 181688  Philippines       5
# 181689        India       6
# 181690  Philippines       5
#                         region_txt        provstate
# 181686          Sub-Saharan Africa  Middle Shebelle
# 181687  Middle East & North Africa         Lattakia
# 181688              Southeast Asia      Maguindanao
# 181689                  South Asia          Manipur
# 181690              Southeast Asia      Maguindanao
#                  city   latitude
# 181686  Ceelka Geelow   2.359673
# 181687         Jableh  35.407278
# 181688       Kubentog   6.900742
# 181689         Imphal  24.798346
# 181690  Cotabato City   7.209594
#          longitude  specificity
# 181686   45.385034          2.0
# 181687   35.942679          1.0
# 181688  124.437908          2.0
# 181689   93.940430          1.0
# 181690  124.241966          1.0
#         vicinity                                           location
# 181686         0     The incident occurred near the town of Balcad.
# 181687         1     The incident occurred at the Humaymim Airport.
# 181688         0  The incident occurred in the Datu Hoffer distr...
# 181689         0  The incident occurred in the Mantripukhri neig...
# 181690         0                                                NaN
#                                                   summary  crit1
# 181686  12/31/2017: Assailants opened fire on a Somali...      1
# 181687  12/31/2017: Assailants launched mortars at the...      1
# 181688  12/31/2017: Assailants set fire to houses in K...      1
# 181689  12/31/2017: Assailants threw a grenade at a Fo...      1
# 181690  12/31/2017: An explosive device was discovered...      1
#         crit2  crit3
# 181686      1      0
# 181687      1      0
# 181688      1      1
# 181689      1      1
# 181690      1      1
#         doubtterr  alternative
# 181686        1.0          1.0
# 181687        1.0          1.0
# 181688        0.0          NaN
# 181689        0.0          NaN
# 181690        0.0          NaN
#                    alternative_txt  multiple
# 181686  Insurgency/Guerilla Action       0.0
# 181687  Insurgency/Guerilla Action       0.0
# 181688                         NaN       0.0
# 181689                         NaN       0.0
# 181690                         NaN       0.0
#         success  suicide
# 181686        1        0
# 181687        1        0
# 181688        1        0
# 181689        0        0
# 181690        0        0
#         attacktype1                 attacktype1_txt
# 181686            2                   Armed Assault
# 181687            3               Bombing/Explosion
# 181688            7  Facility/Infrastructure Attack
# 181689            3               Bombing/Explosion
# 181690            3               Bombing/Explosion
#         attacktype2 attacktype2_txt
# 181686          NaN             NaN
# 181687          NaN             NaN
# 181688          NaN             NaN
# 181689          NaN             NaN
# 181690          NaN             NaN
#         attacktype3 attacktype3_txt
# 181686          NaN             NaN
# 181687          NaN             NaN
# 181688          NaN             NaN
# 181689          NaN             NaN
# 181690          NaN             NaN
#         targtype1                targtype1_txt
# 181686          4                     Military
# 181687          4                     Military
# 181688         14  Private Citizens & Property
# 181689          2         Government (General)
# 181690         20                      Unknown
#         targsubtype1                               targsubtype1_txt
# 181686          36.0                            Military Checkpoint
# 181687          27.0  Military Barracks/Base/Headquarters/Checkpost
# 181688          76.0                      House/Apartment/Residence
# 181689          21.0            Government Building/Facility/Office
# 181690           NaN                                            NaN
#                              corp1           target1
# 181686  Somali National Army (SNA)        Checkpoint
# 181687           Russian Air Force  Hmeymim Air Base
# 181688              Not Applicable            Houses
# 181689   Forest Department Manipur            Office
# 181690                     Unknown           Unknown
#         natlty1  natlty1_txt
# 181686    182.0      Somalia
# 181687    167.0       Russia
# 181688    160.0  Philippines
# 181689     92.0        India
# 181690    160.0  Philippines
#         targtype2 targtype2_txt
# 181686        NaN           NaN
# 181687        NaN           NaN
# 181688        NaN           NaN
# 181689        NaN           NaN
# 181690        NaN           NaN
#         targsubtype2 targsubtype2_txt
# 181686           NaN              NaN
# 181687           NaN              NaN
# 181688           NaN              NaN
# 181689           NaN              NaN
# 181690           NaN              NaN
#        corp2 target2
# 181686   NaN     NaN
# 181687   NaN     NaN
# 181688   NaN     NaN
# 181689   NaN     NaN
# 181690   NaN     NaN
#         natlty2 natlty2_txt
# 181686      NaN         NaN
# 181687      NaN         NaN
# 181688      NaN         NaN
# 181689      NaN         NaN
# 181690      NaN         NaN
#         targtype3 targtype3_txt
# 181686        NaN           NaN
# 181687        NaN           NaN
# 181688        NaN           NaN
# 181689        NaN           NaN
# 181690        NaN           NaN
#         targsubtype3 targsubtype3_txt
# 181686           NaN              NaN
# 181687           NaN              NaN
# 181688           NaN              NaN
# 181689           NaN              NaN
# 181690           NaN              NaN
#        corp3 target3
# 181686   NaN     NaN
# 181687   NaN     NaN
# 181688   NaN     NaN
# 181689   NaN     NaN
# 181690   NaN     NaN
#         natlty3 natlty3_txt
# 181686      NaN         NaN
# 181687      NaN         NaN
# 181688      NaN         NaN
# 181689      NaN         NaN
# 181690      NaN         NaN
#                                              gname gsubname
# 181686                                  Al-Shabaab      NaN
# 181687                           Muslim extremists      NaN
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)      NaN
# 181689                                     Unknown      NaN
# 181690                                     Unknown      NaN
#        gname2 gsubname2
# 181686    NaN       NaN
# 181687    NaN       NaN
# 181688    NaN       NaN
# 181689    NaN       NaN
# 181690    NaN       NaN
#        gname3 gsubname3
# 181686    NaN       NaN
# 181687    NaN       NaN
# 181688    NaN       NaN
# 181689    NaN       NaN
# 181690    NaN       NaN
#        motive  guncertain1
# 181686    NaN          0.0
# 181687    NaN          0.0
# 181688    NaN          0.0
# 181689    NaN          0.0
# 181690    NaN          0.0
#         guncertain2  guncertain3
# 181686          NaN          NaN
# 181687          NaN          NaN
# 181688          NaN          NaN
# 181689          NaN          NaN
# 181690          NaN          NaN
#         individual  nperps
# 181686           0   -99.0
# 181687           0   -99.0
# 181688           0   -99.0
# 181689           0   -99.0
# 181690           0   -99.0
#         nperpcap  claimed
# 181686       0.0      1.0
# 181687       0.0      0.0
# 181688       0.0      0.0
# 181689       0.0      0.0
# 181690       0.0      0.0
#         claimmode claimmode_txt
# 181686       10.0       Unknown
# 181687        NaN           NaN
# 181688        NaN           NaN
# 181689        NaN           NaN
# 181690        NaN           NaN
#         claim2  claimmode2
# 181686     NaN         NaN
# 181687     NaN         NaN
# 181688     NaN         NaN
# 181689     NaN         NaN
# 181690     NaN         NaN
#        claimmode2_txt  claim3
# 181686            NaN     NaN
# 181687            NaN     NaN
# 181688            NaN     NaN
# 181689            NaN     NaN
# 181690            NaN     NaN
#         claimmode3 claimmode3_txt
# 181686         NaN            NaN
# 181687         NaN            NaN
# 181688         NaN            NaN
# 181689         NaN            NaN
# 181690         NaN            NaN
#         compclaim  weaptype1
# 181686        NaN          5
# 181687        NaN          6
# 181688        NaN          8
# 181689        NaN          6
# 181690        NaN          6
#        weaptype1_txt  weapsubtype1
# 181686      Firearms           5.0
# 181687    Explosives          11.0
# 181688    Incendiary          18.0
# 181689    Explosives           7.0
# 181690    Explosives          16.0
#                                  weapsubtype1_txt  weaptype2
# 181686                           Unknown Gun Type        NaN
# 181687  Projectile (rockets, mortars, RPGs, etc.)        NaN
# 181688                                 Arson/Fire        NaN
# 181689                                    Grenade        NaN
# 181690                     Unknown Explosive Type        NaN
#        weaptype2_txt  weapsubtype2
# 181686           NaN           NaN
# 181687           NaN           NaN
# 181688           NaN           NaN
# 181689           NaN           NaN
# 181690           NaN           NaN
#        weapsubtype2_txt  weaptype3
# 181686              NaN        NaN
# 181687              NaN        NaN
# 181688              NaN        NaN
# 181689              NaN        NaN
# 181690              NaN        NaN
#        weaptype3_txt  weapsubtype3
# 181686           NaN           NaN
# 181687           NaN           NaN
# 181688           NaN           NaN
# 181689           NaN           NaN
# 181690           NaN           NaN
#        weapsubtype3_txt  weaptype4
# 181686              NaN        NaN
# 181687              NaN        NaN
# 181688              NaN        NaN
# 181689              NaN        NaN
# 181690              NaN        NaN
#        weaptype4_txt  weapsubtype4
# 181686           NaN           NaN
# 181687           NaN           NaN
# 181688           NaN           NaN
# 181689           NaN           NaN
# 181690           NaN           NaN
#        weapsubtype4_txt                                         weapdetail
# 181686              NaN                                                NaN
# 181687              NaN                   Mortars were used in the attack.
# 181688              NaN                                                NaN
# 181689              NaN           A thrown grenade was used in the attack.
# 181690              NaN  An explosive device containing a detonating co...
#         nkill  nkillus
# 181686    1.0      0.0
# 181687    2.0      0.0
# 181688    0.0      0.0
# 181689    0.0      0.0
# 181690    0.0      0.0
#         nkillter  nwound
# 181686       0.0     2.0
# 181687       0.0     7.0
# 181688       0.0     0.0
# 181689       0.0     0.0
# 181690       0.0     0.0
#         nwoundus  nwoundte
# 181686       0.0       0.0
# 181687       0.0       0.0
# 181688       0.0       0.0
# 181689       0.0       0.0
# 181690       0.0       0.0
#         property  propextent
# 181686        -9         NaN
# 181687         1         4.0
# 181688         1         4.0
# 181689        -9         NaN
# 181690         0         NaN
#        propextent_txt  propvalue
# 181686            NaN        NaN
# 181687        Unknown      -99.0
# 181688        Unknown      -99.0
# 181689            NaN        NaN
# 181690            NaN        NaN
#                                               propcomment  ishostkid
# 181686                                                NaN        0.0
# 181687  Seven military planes were damaged in this att...        0.0
# 181688                Houses were damaged in this attack.        0.0
# 181689                                                NaN        0.0
# 181690                                                NaN        0.0
#         nhostkid  nhostkidus
# 181686       NaN         NaN
# 181687       NaN         NaN
# 181688       NaN         NaN
# 181689       NaN         NaN
# 181690       NaN         NaN
#         nhours  ndays
# 181686     NaN    NaN
# 181687     NaN    NaN
# 181688     NaN    NaN
# 181689     NaN    NaN
# 181690     NaN    NaN
#        divert kidhijcountry
# 181686    NaN           NaN
# 181687    NaN           NaN
# 181688    NaN           NaN
# 181689    NaN           NaN
# 181690    NaN           NaN
#         ransom  ransomamt
# 181686     NaN        NaN
# 181687     NaN        NaN
# 181688     NaN        NaN
# 181689     NaN        NaN
# 181690     NaN        NaN
#         ransomamtus  ransompaid
# 181686          NaN         NaN
# 181687          NaN         NaN
# 181688          NaN         NaN
# 181689          NaN         NaN
# 181690          NaN         NaN
#         ransompaidus ransomnote
# 181686           NaN        NaN
# 181687           NaN        NaN
# 181688           NaN        NaN
# 181689           NaN        NaN
# 181690           NaN        NaN
#         hostkidoutcome hostkidoutcome_txt
# 181686             NaN                NaN
# 181687             NaN                NaN
# 181688             NaN                NaN
# 181689             NaN                NaN
# 181690             NaN                NaN
#         nreleased addnotes
# 181686        NaN      NaN
# 181687        NaN      NaN
# 181688        NaN      NaN
# 181689        NaN      NaN
# 181690        NaN      NaN
#                                                    scite1                                             scite2
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Putin's 'victory' in Syria has turned into a ...  "Two Russian soldiers killed at Hmeymim base i...
# 181688  "Maguindanao clashes trap tribe members," Phil...                                                NaN
# 181689  "Trader escapes grenade attack in Imphal," Bus...                                                NaN
# 181690  "Security tightened in Cotabato following IED ...  "Security tightened in Cotabato City," Manila ...
#                                                    scite3                  dbsource
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...  START Primary Collection
# 181687  "Two Russian servicemen killed in Syria mortar...  START Primary Collection
# 181688                                                NaN  START Primary Collection
# 181689                                                NaN  START Primary Collection
# 181690                                                NaN  START Primary Collection
#         INT_LOG  INT_IDEO
# 181686        0         0
# 181687       -9        -9
# 181688        0         0
# 181689       -9        -9
# 181690       -9        -9
#         INT_MISC  INT_ANY
# 181686         0        0
# 181687         1        1
# 181688         0        0
# 181689         0       -9
# 181690         0       -9

# %%
i,j = 0,2
while j <= 135:
  print(gtd.iloc[:5, i:j])
  i += 2
  j += 2
# Out:
#         eventid  iyear
# 0  197000000001   1970
# 1  197000000002   1970
# 2  197001000001   1970
# 3  197001000002   1970
# 4  197001000003   1970
#    imonth  iday
# 0       7     2
# 1       0     0
# 2       1     0
# 3       1     0
# 4       1     0
#   approxdate  extended
# 0        NaN         0
# 1        NaN         0
# 2        NaN         0
# 3        NaN         0
# 4        NaN         0
#   resolution  country
# 0        NaN       58
# 1        NaN      130
# 2        NaN      160
# 3        NaN       78
# 4        NaN      101
#           country_txt  region
# 0  Dominican Republic       2
# 1              Mexico       1
# 2         Philippines       5
# 3              Greece       8
# 4               Japan       4
#                     region_txt provstate
# 0  Central America & Caribbean       NaN
# 1                North America   Federal
# 2               Southeast Asia    Tarlac
# 3               Western Europe    Attica
# 4                    East Asia   Fukouka
#             city   latitude
# 0  Santo Domingo  18.456792
# 1    Mexico city  19.371887
# 2        Unknown  15.478598
# 3         Athens  37.997490
# 4        Fukouka  33.580412
#     longitude  specificity
# 0  -69.951164          1.0
# 1  -99.086624          1.0
# 2  120.599741          4.0
# 3   23.762728          1.0
# 4  130.396361          1.0
#    vicinity location
# 0         0      NaN
# 1         0      NaN
# 2         0      NaN
# 3         0      NaN
# 4         0      NaN
#   summary  crit1
# 0     NaN      1
# 1     NaN      1
# 2     NaN      1
# 3     NaN      1
# 4     NaN      1
#    crit2  crit3
# 0      1      1
# 1      1      1
# 2      1      1
# 3      1      1
# 4      1      1
#    doubtterr  alternative
# 0        0.0          NaN
# 1        0.0          NaN
# 2        0.0          NaN
# 3        0.0          NaN
# 4       -9.0          NaN
#   alternative_txt  multiple
# 0             NaN       0.0
# 1             NaN       0.0
# 2             NaN       0.0
# 3             NaN       0.0
# 4             NaN       0.0
#    success  suicide
# 0        1        0
# 1        1        0
# 2        1        0
# 3        1        0
# 4        1        0
#    attacktype1                 attacktype1_txt
# 0            1                   Assassination
# 1            6     Hostage Taking (Kidnapping)
# 2            1                   Assassination
# 3            3               Bombing/Explosion
# 4            7  Facility/Infrastructure Attack
#    attacktype2 attacktype2_txt
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN
#    attacktype3 attacktype3_txt
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN
#    targtype1                targtype1_txt
# 0         14  Private Citizens & Property
# 1          7      Government (Diplomatic)
# 2         10          Journalists & Media
# 3          7      Government (Diplomatic)
# 4          7      Government (Diplomatic)
#    targsubtype1                                   targsubtype1_txt
# 0          68.0                                     Named Civilian
# 1          45.0  Diplomatic Personnel (outside of embassy, cons...
# 2          54.0                    Radio Journalist/Staff/Facility
# 3          46.0                                  Embassy/Consulate
# 4          46.0                                  Embassy/Consulate
#                          corp1                  target1
# 0                          NaN             Julio Guzman
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter
# 2             Voice of America                 Employee
# 3                          NaN             U.S. Embassy
# 4                          NaN           U.S. Consulate
#    natlty1         natlty1_txt
# 0     58.0  Dominican Republic
# 1     21.0             Belgium
# 2    217.0       United States
# 3    217.0       United States
# 4    217.0       United States
#    targtype2 targtype2_txt
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
#    targsubtype2 targsubtype2_txt
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN
#   corp2 target2
# 0   NaN     NaN
# 1   NaN     NaN
# 2   NaN     NaN
# 3   NaN     NaN
# 4   NaN     NaN
#    natlty2 natlty2_txt
# 0      NaN         NaN
# 1      NaN         NaN
# 2      NaN         NaN
# 3      NaN         NaN
# 4      NaN         NaN
#    targtype3 targtype3_txt
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
#    targsubtype3 targsubtype3_txt
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN
#   corp3 target3
# 0   NaN     NaN
# 1   NaN     NaN
# 2   NaN     NaN
# 3   NaN     NaN
# 4   NaN     NaN
#    natlty3 natlty3_txt
# 0      NaN         NaN
# 1      NaN         NaN
# 2      NaN         NaN
# 3      NaN         NaN
# 4      NaN         NaN
#                                 gname gsubname
# 0                              MANO-D      NaN
# 1  23rd of September Communist League      NaN
# 2                             Unknown      NaN
# 3                             Unknown      NaN
# 4                             Unknown      NaN
#   gname2 gsubname2
# 0    NaN       NaN
# 1    NaN       NaN
# 2    NaN       NaN
# 3    NaN       NaN
# 4    NaN       NaN
#   gname3 gsubname3
# 0    NaN       NaN
# 1    NaN       NaN
# 2    NaN       NaN
# 3    NaN       NaN
# 4    NaN       NaN
#   motive  guncertain1
# 0    NaN          0.0
# 1    NaN          0.0
# 2    NaN          0.0
# 3    NaN          0.0
# 4    NaN          0.0
#    guncertain2  guncertain3
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#    individual  nperps
# 0           0     NaN
# 1           0     7.0
# 2           0     NaN
# 3           0     NaN
# 4           0     NaN
#    nperpcap  claimed
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN
#    claimmode claimmode_txt
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
#    claim2  claimmode2
# 0     NaN         NaN
# 1     NaN         NaN
# 2     NaN         NaN
# 3     NaN         NaN
# 4     NaN         NaN
#   claimmode2_txt  claim3
# 0            NaN     NaN
# 1            NaN     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN
#    claimmode3 claimmode3_txt
# 0         NaN            NaN
# 1         NaN            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
#    compclaim  weaptype1
# 0        NaN         13
# 1        NaN         13
# 2        NaN         13
# 3        NaN          6
# 4        NaN          8
#   weaptype1_txt  weapsubtype1
# 0       Unknown           NaN
# 1       Unknown           NaN
# 2       Unknown           NaN
# 3    Explosives          16.0
# 4    Incendiary           NaN
#          weapsubtype1_txt  weaptype2
# 0                     NaN        NaN
# 1                     NaN        NaN
# 2                     NaN        NaN
# 3  Unknown Explosive Type        NaN
# 4                     NaN        NaN
#   weaptype2_txt  weapsubtype2
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#   weapsubtype2_txt  weaptype3
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
#   weaptype3_txt  weapsubtype3
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#   weapsubtype3_txt  weaptype4
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
#   weaptype4_txt  weapsubtype4
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#   weapsubtype4_txt  weapdetail
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN   Explosive
# 4              NaN  Incendiary
#    nkill  nkillus
# 0    1.0      NaN
# 1    0.0      NaN
# 2    1.0      NaN
# 3    NaN      NaN
# 4    NaN      NaN
#    nkillter  nwound
# 0       NaN     0.0
# 1       NaN     0.0
# 2       NaN     0.0
# 3       NaN     NaN
# 4       NaN     NaN
#    nwoundus  nwoundte
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#    property  propextent
# 0         0         NaN
# 1         0         NaN
# 2         0         NaN
# 3         1         NaN
# 4         1         NaN
#   propextent_txt  propvalue
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
#   propcomment  ishostkid
# 0         NaN        0.0
# 1         NaN        1.0
# 2         NaN        0.0
# 3         NaN        0.0
# 4         NaN        0.0
#    nhostkid  nhostkidus
# 0       NaN         NaN
# 1       1.0         0.0
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
#    nhours  ndays
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
#   divert kidhijcountry
# 0    NaN           NaN
# 1    NaN        Mexico
# 2    NaN           NaN
# 3    NaN           NaN
# 4    NaN           NaN
#    ransom  ransomamt
# 0     0.0        NaN
# 1     1.0   800000.0
# 2     0.0        NaN
# 3     0.0        NaN
# 4     0.0        NaN
#    ransomamtus  ransompaid
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
#    ransompaidus ransomnote
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
#    hostkidoutcome hostkidoutcome_txt
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
#    nreleased addnotes
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
#   scite1 scite2
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#   scite3 dbsource
# 0    NaN     PGIS
# 1    NaN     PGIS
# 2    NaN     PGIS
# 3    NaN     PGIS
# 4    NaN     PGIS
#    INT_LOG  INT_IDEO
# 0        0         0
# 1        0         1
# 2       -9        -9
# 3       -9        -9
# 4       -9        -9
#    INT_MISC  INT_ANY
# 0         0        0
# 1         1        1
# 2         1        1
# 3         1        1
# 4         1        1

# %%
print(gtd['suicide'].value_counts())
# Out:
# 0    175058
# 1      6633
# Name: suicide, dtype: int64

# %% [markdown]
# #### Feature Extraction

# %%
GTD_FEATURE_NAMES = ['alternative_txt','attacktype1_txt','attacktype2_txt',
                     'attacktype3_txt','gname','gname2','gname3','gsubname',
                     'gsubname2','gsubname3','scite1','scite2','scite3',
                     'summary','target1','targtype1_txt','targsubtype1_txt',
                     'target2','targtype2_txt','targsubtype2_txt','target3',
                     'targtype3_txt','targsubtype3_txt','weapdetail',
                     'weaptype1_txt','weapsubtype1_txt','weaptype2_txt',
                     'weapsubtype2_txt','weaptype3_txt','weapsubtype3_txt',
                     'weaptype4_txt','weapsubtype4_txt']

# %%
gtd_view1 = gtd[GTD_FEATURE_NAMES]

# %%
# EXTRACT COLUMNS WHICH HAVE ATTACK TYPES
ATTACK_TYPE_COLS = ['attacktype1_txt','attacktype2_txt','attacktype3_txt']
gtd_view_attacks = gtd_view1.dropna(
    how='all',
    subset=ATTACK_TYPE_COLS)

# %%
# EXTRACT UNIQUE ATTACK TYPES
ATTACK_TYPES = [attacktype for attacktype in
                set().union(*[set(gtd_view_attacks[attacktype_col])
                for attacktype_col in ATTACK_TYPE_COLS])
                if attacktype==attacktype]  # We know that, nan != nan

# %%
ATTACK_TYPES
# Out:
# ['Unknown',
#  'Hijacking',
#  'Hostage Taking (Kidnapping)',
#  'Facility/Infrastructure Attack',
#  'Hostage Taking (Barricade Incident)',
#  'Armed Assault',
#  'Bombing/Explosion',
#  'Assassination',
#  'Unarmed Assault']

# %%
# EXTRACT COLUMNS WHICH HAVE WEAPON TYPES ## 'weapdetail', 
WEAPON_TYPE_COLS = ['weaptype1_txt','weapsubtype1_txt',
                    'weaptype2_txt','weapsubtype2_txt','weaptype3_txt',
                    'weapsubtype3_txt','weaptype4_txt','weapsubtype4_txt']

gtd_view_weapons = gtd_view1.dropna(
    how='all',
    subset=WEAPON_TYPE_COLS)

# %%
# EXTRACT UNIQUE WEAPON TYPES
WEAPON_TYPES = [weapontype for weapontype in
                set().union(*[set(gtd_view_weapons[weapontype_col])
                for weapontype_col in WEAPON_TYPE_COLS])
                if weapontype==weapontype] # We know that, nan != nan

# %%
WEAPON_TYPES
# Out:
# ['Other Gun Type',
#  'Firearms',
#  'Other',
#  'Remote Trigger',
#  'Grenade',
#  'Melee',
#  'Unknown Weapon Type',
#  'Unknown',
#  'Molotov Cocktail/Petrol Bomb',
#  'Suicide (carried bodily by human being)',
#  'Chemical',
#  'Pressure Trigger',
#  'Poisoning',
#  'Incendiary',
#  'Letter Bomb',
#  'Projectile (rockets, mortars, RPGs, etc.)',
#  'Automatic or Semi-Automatic Rifle',
#  'Rifle/Shotgun (non-automatic)',
#  'Explosive',
#  'Time Fuse',
#  'Rope or Other Strangling Device',
#  'Unknown Explosive Type',
#  'Sticky Bomb',
#  'Explosives',
#  'Landmine',
#  'Biological',
#  'Handgun',
#  'Sabotage Equipment',
#  'Other Explosive Type',
#  'Knife or Other Sharp Object',
#  'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
#  'Pipe Bomb',
#  'Hands, Feet, Fists',
#  'Gasoline or Alcohol',
#  'Blunt Object',
#  'Radiological',
#  'Vehicle',
#  'Arson/Fire',
#  'Dynamite/TNT',
#  'Suffocation',
#  'Unknown Gun Type',
#  'Fake Weapons']

# %% [markdown]
# ### RDWTI (RAND Database of Wordwide Terrorism Incidents)

# %% [markdown]
# #### Load database

# %%
rdwti = pd.read_csv(RDWTI, engine=ENGINE, encoding=ENCODING)

# %% [markdown]
# #### EDA

# %%
print(rdwti.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40129 entries, 0 to 40128
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         40129 non-null  object
#  1   City         35155 non-null  object
#  2   Country      40129 non-null  object
#  3   Perpetrator  40125 non-null  object
#  4   Weapon       40126 non-null  object
#  5   Injuries     40129 non-null  int64
#  6   Fatalities   40129 non-null  int64
#  7   Description  40128 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 2.4+ MB
# None

# %%
print(rdwti.head())
# Out:
#         Date  ...                                        Description
# 0   9-Feb-68  ...  ARGENTINA.  The second floor of the U.S. embas...
# 1  12-Feb-68  ...  DOMINICAN REPUBLIC.  A homemade bomb was found...
# 2  13-Feb-68  ...  URUGUAY.  A Molotov cocktail was thrown outsid...
# 3  20-Feb-68  ...  CHILE.  An explosion from a single stick of dy...
# 4  21-Feb-68  ...  UNITED STATES.  The Soviet embassy was bombed ...
#
# [5 rows x 8 columns]

# %%
print(rdwti['Description'][0])
# Out:
# ARGENTINA.  The second floor of the U.S. embassy residence was struck by fifteen 9-mm machine-gun slugs fired from a passing automobile during the early morning hours.

# %%
print(rdwti['Perpetrator'].value_counts())
# Out:
# Unknown                                          26190
# Other                                             2057
# Taliban                                           1000
# Revolutionary Armed Forces of Colombia (FARC)      616
# Hamas (Islamic Resistance Movement)                576
#                                                  ...
# al-Fahd al-Aswad Forces                              1
# South Londonderry Volunteers                         1
# Ogaden National Liberation Front (ONLF)              1
# Jordanian Islamic Resistance                         1
# June 2  Movement (Bewegung 2 Juni)                   1
# Name: Perpetrator, Length: 1059, dtype: int64

# %%
print(rdwti['Weapon'].value_counts())
# Out:
# Explosives                    20523
# Firearms                      11222
# Unknown                        3213
# Fire or Firebomb               2778
# Remote-detonated explosive     1593
# Knives & sharp objects          418
# Other                           304
# Chemical Agent                   59
# Biological Agent                 13
# Telecommunication                 1
# Bombing                           1
# Business                          1
# Name: Weapon, dtype: int64

# %%
print(rdwti['Injuries'].value_counts())
# Out:
# 0       27571
# 1        3137
# 2        2092
# 3        1384
# 4        1032
#         ...
# 625         1
# 178         1
# 1042        1
# 84          1
# 111         1
# Name: Injuries, Length: 176, dtype: int64

# %%
print(rdwti['Fatalities'].value_counts())
# Out:
# 0      24597
# 1       7965
# 2       2697
# 3       1325
# 4        830
#        ...
# 115        1
# 500        1
# 85         1
# 117        1
# 79         1
# Name: Fatalities, Length: 121, dtype: int64

# %%
print(rdwti['Country'].value_counts())
# Out:
# Iraq                   10763
# West Bank/Gaza          2038
# Afghanistan             2025
# Thailand                2009
# Colombia                1913
#                        ...
# Iceland                    1
# Trucial Oman States        1
# Hong Kong                  1
# Falkland Islands           1
# Taiwan                     1
# Name: Country, Length: 195, dtype: int64

# %% [markdown]
# #### Feature Extraction

# %%
RDWTI_FEATURE_NAMES = ['Description','Weapon','Perpetrator']

# %%
rdwti_view1 = rdwti[RDWTI_FEATURE_NAMES]

# %%
# EXTRACT UNIQUE WEAPONS
RDWTI_WEAPONS = [weapontype for weapontype in
                 set(rdwti_view1['Weapon'].values)
                 if weapontype == weapontype]

# %%
RDWTI_WEAPONS
# Out:
# ['Unknown',
#  'Chemical Agent',
#  'Remote-detonated explosive',
#  'Business',
#  'Knives & sharp objects',
#  'Firearms',
#  'Other',
#  'Bombing',
#  'Explosives',
#  'Telecommunication',
#  'Biological Agent',
#  'Fire or Firebomb']

# %% [markdown]
# ### FIRE Dataset

# %% [markdown]
# #### Load Dataset

# %%
firedataset = pickle.load(open(FIRE_DATA_DICT, 'rb'))
firedataset_filedata_list = list(zip(*firedataset.values()))[0]
firedataset_filename_list = list(zip(*firedataset.values()))[1]

# %%
firedataset_filename_list[:5]
# Out:
# ('1041207_atleisure_index.utf8',
#  '1041208_atleisure_index.utf8',
#  '1041210_atleisure_index.utf8',
#  '1041211_atleisure_index.utf8',
#  '1041213_atleisure_index.utf8')

# %% [markdown]
# ## Load Trigger Dictionary

# %%
TERRORIST_EVENTS_UPDATED = pickle.load(open(TERRORIST_EVENTS_UPDATED1_PATH, 'rb'))

# %%
TERRORIST_EVENTS_UPDATED.keys()
# Out:
# odict_keys(['Assassination', 'Armed Assault', 'Facility/Infrastructure Attack', 'Unarmed Assault', 'Hijacking', 'Bombing/Explosion', 'Cyberattacks', 'Hostage'])

# %%
def classify_file(doc, trigger_dict):
  global PORTER
  all_string = string.ascii_letters+string.digits+\
  string.punctuation+string.whitespace
  for event, trigger_list in trigger_dict.items():
    if trigger_list != []:
      for trigger in trigger_list:
        if trigger:
          if trigger in doc:
            return event
          else:
            trigger_words_list = trigger.split()
            pattern = r'[a-zA-Z0-9 !"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~]*'
            new_pattern = pattern.join([PORTER.stem(word) for word in (trigger_words_list)])
            if re.search(new_pattern, doc):
              return event
  return 'Unknown Event'

# %%
# test_summary_list = list(gtd[gtd['attacktype1_txt'] == 'Assassination']['summary'])
# attack_type = 'Assassination'

TP_FP_FN_gtd_dict = OrderedDict()
for key in TERRORIST_EVENTS_UPDATED.keys():
  TP_FP_FN_gtd_dict[key] = {'TP':0, 'FP':0, 'FN':0}

# %%
def test_summary(attacktype_col, attack_type, test_column):
  global TP_FP_FN_gtd_dict

  if attack_type == 'Hostage':
    gtd1 = gtd[gtd[attacktype_col] == 'Hostage Taking (Barricade Incident)']
    # gtd1 = gtd[gtd[attacktype_col] == 'Hostage Taking (Kidnapping)']
  else:
    gtd1 = gtd[gtd[attacktype_col] == attack_type]

  errors = 0 # correct classification count
  correct = 0 # wrong classification count
  correct_as_attack_type = 0
  misclassified_as = list()
  classified_as = list()

  for idx, row in gtd1.iterrows():
    if row[test_column] == row[test_column]:
      result = classify_file(row[test_column], TERRORIST_EVENTS_UPDATED)
      if result != 'Unknown Event':
        if (result != attack_type) and \
        (result != row['attacktype2_txt']) and \
        (result != row['attacktype3_txt']) :
            errors += 1
            if result not in misclassified_as:
              misclassified_as.append(result)
            TP_FP_FN_gtd_dict[result]['FP'] += 1
            TP_FP_FN_gtd_dict[attack_type]['FN'] += 1
        else:
          if result == attack_type:
            TP_FP_FN_gtd_dict[result]['TP'] += 1
            correct_as_attack_type += 1
          else:
            TP_FP_FN_gtd_dict[attack_type]['FN'] += 1
            if result not in classified_as:
              classified_as.append(result)
          correct += 1
      # else:
        # print(row[test_column], end='\n\n')
        # print('\n\nNot detected\n\n')
  
  sep_len = len('Facility/Infrastructure Attack')
  sep_str = " "*sep_len

  print(f'Attack type                         {sep_str}   : {attack_type}')
  print(f'Correct classification as           {attack_type:30}   : {correct_as_attack_type}')
  print(f'Correct classification              {sep_str}   : {correct}')
  print(f'Other correct classification into   {sep_str}   : {classified_as}')
  print(f'Incorrect classification            {sep_str}   : {errors}')
  print(f'Misclassification into              {sep_str}   : {misclassified_as}')
  
  print('='*100)
  return correct, errors

# %%
### NEW based on all attack type cols of that 
def test(test_column, attacktype_col):
  global TERRORIST_EVENTS_UPDATED
  for attacktype in TERRORIST_EVENTS_UPDATED.keys():
    test_summary(attacktype_col, attacktype, test_column)

# %%
attacktype_col = 'attacktype1_txt'
test_column = 'summary'
test(test_column, attacktype_col)
# Out:
# Attack type                                                          : Assassination
# Correct classification as           Assassination                    : 405
# Correct classification                                               : 409
# Other correct classification into                                    : ['Bombing/Explosion', 'Armed Assault']
# Incorrect classification                                             : 4269
# Misclassification into                                               : ['Armed Assault', 'Bombing/Explosion', 'Hijacking', 'Facility/Infrastructure Attack', 'Hostage', 'Unarmed Assault']
# ====================================================================================================
# Attack type                                                          : Armed Assault
# Correct classification as           Armed Assault                    : 13465
# Correct classification                                               : 13635
# Other correct classification into                                    : ['Bombing/Explosion', 'Facility/Infrastructure Attack', 'Assassination', 'Hijacking']
# Incorrect classification                                             : 1342
# Misclassification into                                               : ['Facility/Infrastructure Attack', 'Assassination', 'Hostage', 'Hijacking', 'Unarmed Assault', 'Bombing/Explosion']
# ====================================================================================================
# Attack type                                                          : Facility/Infrastructure Attack
# Correct classification as           Facility/Infrastructure Attack   : 1873
# Correct classification                                               : 1902
# Other correct classification into                                    : ['Armed Assault', 'Bombing/Explosion']
# Incorrect classification                                             : 663
# Misclassification into                                               : ['Bombing/Explosion', 'Armed Assault', 'Unarmed Assault', 'Assassination', 'Hostage', 'Hijacking']
# ====================================================================================================
# Attack type                                                          : Unarmed Assault
# Correct classification as           Unarmed Assault                  : 33
# Correct classification                                               : 49
# Other correct classification into                                    : ['Facility/Infrastructure Attack']
# Incorrect classification                                             : 64
# Misclassification into                                               : ['Bombing/Explosion', 'Facility/Infrastructure Attack', 'Hijacking', 'Armed Assault', 'Assassination']
# ====================================================================================================
# Attack type                                                          : Hijacking
# Correct classification as           Hijacking                        : 163
# Correct classification                                               : 178
# Other correct classification into                                    : ['Armed Assault', 'Facility/Infrastructure Attack']
# Incorrect classification                                             : 54
# Misclassification into                                               : ['Bombing/Explosion', 'Assassination', 'Armed Assault', 'Hostage', 'Unarmed Assault', 'Facility/Infrastructure Attack']
# ====================================================================================================
# Attack type                                                          : Bombing/Explosion
# Correct classification as           Bombing/Explosion                : 20284
# Correct classification                                               : 21110
# Other correct classification into                                    : ['Facility/Infrastructure Attack', 'Armed Assault', 'Assassination', 'Hijacking', 'Unarmed Assault']
# Incorrect classification                                             : 6952
# Misclassification into                                               : ['Facility/Infrastructure Attack', 'Armed Assault', 'Unarmed Assault', 'Assassination', 'Hijacking', 'Hostage', 'Cyberattacks']
# ====================================================================================================
# Attack type                                                          : Cyberattacks
# Correct classification as           Cyberattacks                     : 0
# Correct classification                                               : 0
# Other correct classification into                                    : []
# Incorrect classification                                             : 0
# Misclassification into                                               : []
# ====================================================================================================
# Attack type                                                          : Hostage
# Correct classification as           Hostage                          : 124
# Correct classification                                               : 207
# Other correct classification into                                    : ['Armed Assault', 'Bombing/Explosion', 'Facility/Infrastructure Attack']
# Incorrect classification                                             : 53
# Misclassification into                                               : ['Bombing/Explosion', 'Armed Assault', 'Hijacking', 'Unarmed Assault', 'Facility/Infrastructure Attack']
# ====================================================================================================

# %%
for key, value in TP_FP_FN_gtd_dict.items():
  try:
    print(key, value)
    precision = value['TP']/(value['TP']+value['FP'])
    recall = value['TP']/(value['TP']+value['FN'])
    f1_score = 2 * (recall * precision) / (recall + precision)
    print('Attack type               :', key)
    print('Precision                 :', precision)
    print('Recall                    :', recall)
    print('F1 Score                  :', f1_score)
  except:
    pass
  finally:
    print('='*100)
# Out:
# Assassination {'TP': 810, 'FP': 330, 'FN': 4277}
# Attack type               : Assassination
# Precision                 : 0.7105263157894737
# Recall                    : 0.1592294082956556
# F1 Score                  : 0.26015737915529147
# ====================================================================================================
# Armed Assault {'TP': 26930, 'FP': 7890, 'FN': 1682}
# Attack type               : Armed Assault
# Precision                 : 0.773406088454911
# Recall                    : 0.9412134768628547
# F1 Score                  : 0.8490982469416067
# ====================================================================================================
# Facility/Infrastructure Attack {'TP': 3746, 'FP': 15158, 'FN': 721}
# Attack type               : Facility/Infrastructure Attack
# Precision                 : 0.19815911976301312
# Recall                    : 0.8385941347660623
# F1 Score                  : 0.3205682255787087
# ====================================================================================================
# Unarmed Assault {'TP': 66, 'FP': 964, 'FN': 96}
# Attack type               : Unarmed Assault
# Precision                 : 0.06407766990291262
# Recall                    : 0.4074074074074074
# F1 Score                  : 0.11073825503355705
# ====================================================================================================
# Hijacking {'TP': 326, 'FP': 114, 'FN': 84}
# Attack type               : Hijacking
# Precision                 : 0.740909090909091
# Recall                    : 0.7951219512195122
# F1 Score                  : 0.7670588235294119
# ====================================================================================================
# Bombing/Explosion {'TP': 40568, 'FP': 2068, 'FN': 8604}
# Attack type               : Bombing/Explosion
# Precision                 : 0.9514963880288958
# Recall                    : 0.8250223704547304
# F1 Score                  : 0.8837574067619379
# ====================================================================================================
# Cyberattacks {'TP': 0, 'FP': 2, 'FN': 0}
# ====================================================================================================
# Hostage {'TP': 248, 'FP': 268, 'FN': 219}
# Attack type               : Hostage
# Precision                 : 0.4806201550387597
# Recall                    : 0.5310492505353319
# F1 Score                  : 0.5045778229908444
# ====================================================================================================

# %%
def trigger_dict_add_triggers(event, trigger):
  global TERRORIST_EVENTS_UPDATED
  global TERRORIST_EVENTS_UPDATED1_PATH
  TERRORIST_EVENTS_UPDATED[event].append(trigger)
  TERRORIST_EVENTS_UPDATED[event] = list(set(TERRORIST_EVENTS_UPDATED[event]))
  TERRORIST_EVENTS_UPDATED[event].sort()
  pickle.dump(TERRORIST_EVENTS_UPDATED, open(TERRORIST_EVENTS_UPDATED1_PATH, 'wb'))
  TERRORIST_EVENTS_UPDATED = pickle.load(open(TERRORIST_EVENTS_UPDATED1_PATH, 'rb'))

# %%
event = 'Bombing/Explosion'
trigger = 'detonated explosives'
trigger_dict_add_triggers(event, trigger)
TERRORIST_EVENTS_UPDATED[event]
## TERRORIST_EVENTS_UPDATED[event].remove(trigger)

# %%
events_firedataset = list()
for data in firedataset_filedata_list[:]:
  events_firedataset.append(classify_file(data, TERRORIST_EVENTS_UPDATED))

# %%
for i in range(1000):
  print(f'{events_firedataset[i]:50} {firedataset_filename_list[i]}\n')
# Out:
# Unknown Event                                      1041207_atleisure_index.utf8
#
# Unknown Event                                      1041208_atleisure_index.utf8
#
# Unknown Event                                      1041210_atleisure_index.utf8
#
# Unknown Event                                      1041211_atleisure_index.utf8
#
# Unknown Event                                      1041213_atleisure_index.utf8
#
# Unknown Event                                      1041213_atleisure_story_4109250.utf8
#
# Unknown Event                                      1041213_atleisure_story_4121739.utf8
#
# Unknown Event                                      1041213_atleisure_story_4121740.utf8
#
# Unknown Event                                      1041213_atleisure_story_4121741.utf8
#
# Unknown Event                                      1041213_atleisure_story_4122608.utf8
#
# Unknown Event                                      1041214_atleisure_index.utf8
#
# Unknown Event                                      1041214_atleisure_story_4104626.utf8
#
# Unknown Event                                      1041214_atleisure_story_4123870.utf8
#
# Unknown Event                                      1041214_atleisure_story_4125737.utf8
#
# Unknown Event                                      1041214_atleisure_story_4125738.utf8
#
# Facility/Infrastructure Attack                     1041214_atleisure_story_4125739.utf8
#
# Unknown Event                                      1041215_atleisure_index.utf8
#
# Unknown Event                                      1041215_atleisure_story_4127714.utf8
#
# Unknown Event                                      1041215_atleisure_story_4130259.utf8
#
# Unknown Event                                      1041215_atleisure_story_4130260.utf8
#
# Bombing/Explosion                                  1041215_atleisure_story_4131410.utf8
#
# Unknown Event                                      1041217_atleisure_index.utf8
#
# Unknown Event                                      1041217_atleisure_story_4127399.utf8
#
# Unknown Event                                      1041217_atleisure_story_4127400.utf8
#
# Unknown Event                                      1041217_atleisure_story_4127402.utf8
#
# Unknown Event                                      1041217_atleisure_story_4139383.utf8
#
# Unknown Event                                      1041217_atleisure_story_4139384.utf8
#
# Unknown Event                                      1041217_atleisure_story_4140664.utf8
#
# Unknown Event                                      1041218_atleisure_index.utf8
#
# Unknown Event                                      1041218_atleisure_story_4136553.utf8
#
# Unknown Event                                      1041218_atleisure_story_4144088.utf8
#
# Unknown Event                                      1041218_atleisure_story_4144090.utf8
#
# Unknown Event                                      1041220_atleisure_index.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151049.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151050.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151051.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151052.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151053.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151931.utf8
#
# Unknown Event                                      1041220_atleisure_story_4151935.utf8
#
# Unknown Event                                      1041221_atleisure_index.utf8
#
# Unknown Event                                      1041221_atleisure_story_4152103.utf8
#
# Unknown Event                                      1041221_atleisure_story_4152161.utf8
#
# Facility/Infrastructure Attack                     1041221_atleisure_story_4155153.utf8
#
# Unknown Event                                      1041221_atleisure_story_4155154.utf8
#
# Unknown Event                                      1041221_atleisure_story_4155155.utf8
#
# Unknown Event                                      1041221_atleisure_story_4155156.utf8
#
# Unknown Event                                      1041222_atleisure_index.utf8
#
# Unknown Event                                      1041222_atleisure_story_4157661.utf8
#
# Unknown Event                                      1041222_atleisure_story_4159405.utf8
#
# Unknown Event                                      1041222_atleisure_story_4159406.utf8
#
# Unknown Event                                      1041222_atleisure_story_4159407.utf8
#
# Unknown Event                                      1041222_atleisure_story_4160535.utf8
#
# Unknown Event                                      1041224_atleisure_index.utf8
#
# Unknown Event                                      1041224_atleisure_story_4157084.utf8
#
# Unknown Event                                      1041224_atleisure_story_4157118.utf8
#
# Unknown Event                                      1041224_atleisure_story_4168326.utf8
#
# Unknown Event                                      1041224_atleisure_story_4168585.utf8
#
# Armed Assault                                      1041224_atleisure_story_4168586.utf8
#
# Unknown Event                                      1041224_atleisure_story_4168587.utf8
#
# Unknown Event                                      1041224_atleisure_story_4169713.utf8
#
# Unknown Event                                      1041225_atleisure_index.utf8
#
# Armed Assault                                      1041225_atleisure_story_4170517.utf8
#
# Unknown Event                                      1041225_atleisure_story_4172862.utf8
#
# Unknown Event                                      1041225_atleisure_story_4172864.utf8
#
# Unknown Event                                      1041225_atleisure_story_4172865.utf8
#
# Unknown Event                                      1041227_atleisure_index.utf8
#
# Unknown Event                                      1041227_atleisure_story_4166269.utf8
#
# Unknown Event                                      1041227_atleisure_story_4170844.utf8
#
# Unknown Event                                      1041227_atleisure_story_4179432.utf8
#
# Unknown Event                                      1041227_atleisure_story_4179433.utf8
#
# Unknown Event                                      1041227_atleisure_story_4179434.utf8
#
# Unknown Event                                      1041227_atleisure_story_4179435.utf8
#
# Unknown Event                                      1041228_atleisure_index.utf8
#
# Unknown Event                                      1041228_atleisure_story_4174742.utf8
#
# Unknown Event                                      1041228_atleisure_story_4180558.utf8
#
# Unknown Event                                      1041229_atleisure_index.utf8
#
# Unknown Event                                      1041229_atleisure_story_4167555.utf8
#
# Unknown Event                                      1041229_atleisure_story_4188371.utf8
#
# Unknown Event                                      1041231_atleisure_index.utf8
#
# Unknown Event                                      1041231_atleisure_story_4181185.utf8
#
# Unknown Event                                      1041231_atleisure_story_4181188.utf8
#
# Unknown Event                                      1041231_atleisure_story_4181195.utf8
#
# Unknown Event                                      1041231_atleisure_story_4196058.utf8
#
# Unknown Event                                      1040901_bengal_index.utf8
#
# Unknown Event                                      1040901_bengal_story_3702359.utf8
#
# Unknown Event                                      1040901_bengal_story_3702360.utf8
#
# Unknown Event                                      1040901_bengal_story_3702361.utf8
#
# Unknown Event                                      1040901_bengal_story_3702362.utf8
#
# Facility/Infrastructure Attack                     1040901_bengal_story_3702363.utf8
#
# Unknown Event                                      1040901_bengal_story_3702364.utf8
#
# Unknown Event                                      1040902_bengal_index.utf8
#
# Unknown Event                                      1040902_bengal_story_3706193.utf8
#
# Unknown Event                                      1040902_bengal_story_3707327.utf8
#
# Armed Assault                                      1040902_bengal_story_3707328.utf8
#
# Unknown Event                                      1040902_bengal_story_3707329.utf8
#
# Unknown Event                                      1040902_bengal_story_3707331.utf8
#
# Unknown Event                                      1040902_bengal_story_3707852.utf8
#
# Unknown Event                                      1040903_bengal_index.utf8
#
# Unknown Event                                      1040903_bengal_story_3711731.utf8
#
# Unknown Event                                      1040903_bengal_story_3711732.utf8
#
# Facility/Infrastructure Attack                     1040903_bengal_story_3711734.utf8
#
# Unknown Event                                      1040903_bengal_story_3711819.utf8
#
# Unknown Event                                      1040903_bengal_story_3711897.utf8
#
# Unknown Event                                      1040903_bengal_story_3712822.utf8
#
# Unknown Event                                      1040903_bengal_story_3712823.utf8
#
# Unknown Event                                      1040904_bengal_index.utf8
#
# Unknown Event                                      1040904_bengal_story_3716204.utf8
#
# Unknown Event                                      1040904_bengal_story_3716205.utf8
#
# Unknown Event                                      1040904_bengal_story_3716206.utf8
#
# Unknown Event                                      1040904_bengal_story_3716207.utf8
#
# Unknown Event                                      1040904_bengal_story_3716486.utf8
#
# Unknown Event                                      1040905_bengal_index.utf8
#
# Unknown Event                                      1040905_bengal_story_3719222.utf8
#
# Unknown Event                                      1040905_bengal_story_3719880.utf8
#
# Unknown Event                                      1040905_bengal_story_3719881.utf8
#
# Unknown Event                                      1040905_bengal_story_3719882.utf8
#
# Unknown Event                                      1040905_bengal_story_3719883.utf8
#
# Unknown Event                                      1040905_bengal_story_3719885.utf8
#
# Unknown Event                                      1040905_bengal_story_3719887.utf8
#
# Unknown Event                                      1040905_bengal_story_3719930.utf8
#
# Unknown Event                                      1040905_bengal_story_3719931.utf8
#
# Unknown Event                                      1040905_bengal_story_3719932.utf8
#
# Unknown Event                                      1040905_bengal_story_3719933.utf8
#
# Unknown Event                                      1040905_bengal_story_3719934.utf8
#
# Unknown Event                                      1040905_bengal_story_3719935.utf8
#
# Unknown Event                                      1040906_bengal_index.utf8
#
# Unknown Event                                      1040906_bengal_story_3723219.utf8
#
# Unknown Event                                      1040906_bengal_story_3723220.utf8
#
# Unknown Event                                      1040906_bengal_story_3723221.utf8
#
# Unknown Event                                      1040906_bengal_story_3723222.utf8
#
# Unknown Event                                      1040906_bengal_story_3723223.utf8
#
# Unknown Event                                      1040906_bengal_story_3723224.utf8
#
# Unknown Event                                      1040906_bengal_story_3723566.utf8
#
# Unknown Event                                      1040907_bengal_index.utf8
#
# Facility/Infrastructure Attack                     1040907_bengal_story_3726693.utf8
#
# Unknown Event                                      1040907_bengal_story_3727082.utf8
#
# Unknown Event                                      1040907_bengal_story_3727083.utf8
#
# Unknown Event                                      1040907_bengal_story_3727084.utf8
#
# Unknown Event                                      1040907_bengal_story_3727432.utf8
#
# Unknown Event                                      1040908_bengal_index.utf8
#
# Unknown Event                                      1040908_bengal_story_3731388.utf8
#
# Unknown Event                                      1040908_bengal_story_3731624.utf8
#
# Unknown Event                                      1040908_bengal_story_3731625.utf8
#
# Unknown Event                                      1040908_bengal_story_3731626.utf8
#
# Unknown Event                                      1040908_bengal_story_3731627.utf8
#
# Unknown Event                                      1040908_bengal_story_3731628.utf8
#
# Unknown Event                                      1040908_bengal_story_3731629.utf8
#
# Unknown Event                                      1040909_bengal_index.utf8
#
# Unknown Event                                      1040909_bengal_story_3735938.utf8
#
# Unknown Event                                      1040909_bengal_story_3735939.utf8
#
# Unknown Event                                      1040909_bengal_story_3735940.utf8
#
# Unknown Event                                      1040909_bengal_story_3735941.utf8
#
# Unknown Event                                      1040909_bengal_story_3736219.utf8
#
# Unknown Event                                      1040910_bengal_index.utf8
#
# Unknown Event                                      1040910_bengal_story_3740568.utf8
#
# Unknown Event                                      1040910_bengal_story_3740569.utf8
#
# Unknown Event                                      1040910_bengal_story_3740570.utf8
#
# Unknown Event                                      1040910_bengal_story_3740571.utf8
#
# Unknown Event                                      1040910_bengal_story_3740572.utf8
#
# Unknown Event                                      1040910_bengal_story_3740749.utf8
#
# Unknown Event                                      1040911_bengal_index.utf8
#
# Unknown Event                                      1040911_bengal_story_3745204.utf8
#
# Unknown Event                                      1040911_bengal_story_3745205.utf8
#
# Unknown Event                                      1040911_bengal_story_3745206.utf8
#
# Unknown Event                                      1040911_bengal_story_3745207.utf8
#
# Unknown Event                                      1040911_bengal_story_3745208.utf8
#
# Unknown Event                                      1040911_bengal_story_3745209.utf8
#
# Bombing/Explosion                                  1040912_bengal_index.utf8
#
# Unknown Event                                      1040912_bengal_story_3747493.utf8
#
# Unknown Event                                      1040912_bengal_story_3748047.utf8
#
# Unknown Event                                      1040912_bengal_story_3748048.utf8
#
# Unknown Event                                      1040912_bengal_story_3748049.utf8
#
# Unknown Event                                      1040912_bengal_story_3748050.utf8
#
# Unknown Event                                      1040912_bengal_story_3748051.utf8
#
# Unknown Event                                      1040912_bengal_story_3748213.utf8
#
# Armed Assault                                      1040912_bengal_story_3748214.utf8
#
# Bombing/Explosion                                  1040912_bengal_story_3748216.utf8
#
# Unknown Event                                      1040912_bengal_story_3748217.utf8
#
# Unknown Event                                      1040912_bengal_story_3748218.utf8
#
# Unknown Event                                      1040912_bengal_story_3748219.utf8
#
# Unknown Event                                      1040913_bengal_index.utf8
#
# Unknown Event                                      1040913_bengal_story_3751320.utf8
#
# Unknown Event                                      1040913_bengal_story_3751322.utf8
#
# Unknown Event                                      1040913_bengal_story_3751324.utf8
#
# Unknown Event                                      1040913_bengal_story_3751325.utf8
#
# Unknown Event                                      1040913_bengal_story_3751326.utf8
#
# Armed Assault                                      1040913_bengal_story_3751551.utf8
#
# Unknown Event                                      1040914_bengal_index.utf8
#
# Unknown Event                                      1040914_bengal_story_3755342.utf8
#
# Unknown Event                                      1040914_bengal_story_3755343.utf8
#
# Unknown Event                                      1040914_bengal_story_3755344.utf8
#
# Unknown Event                                      1040914_bengal_story_3755345.utf8
#
# Unknown Event                                      1040914_bengal_story_3755346.utf8
#
# Unknown Event                                      1040914_bengal_story_3755349.utf8
#
# Unknown Event                                      1040915_bengal_index.utf8
#
# Unknown Event                                      1040915_bengal_story_3760154.utf8
#
# Unknown Event                                      1040915_bengal_story_3760155.utf8
#
# Unknown Event                                      1040915_bengal_story_3760156.utf8
#
# Unknown Event                                      1040915_bengal_story_3760157.utf8
#
# Unknown Event                                      1040915_bengal_story_3760158.utf8
#
# Unknown Event                                      1040915_bengal_story_3760159.utf8
#
# Unknown Event                                      1040915_bengal_story_3760160.utf8
#
# Unknown Event                                      1040915_bengal_story_3760161.utf8
#
# Unknown Event                                      1040916_bengal_index.utf8
#
# Unknown Event                                      1040916_bengal_story_3764186.utf8
#
# Unknown Event                                      1040916_bengal_story_3764187.utf8
#
# Unknown Event                                      1040916_bengal_story_3764188.utf8
#
# Unknown Event                                      1040916_bengal_story_3764189.utf8
#
# Unknown Event                                      1040916_bengal_story_3764190.utf8
#
# Unknown Event                                      1040916_bengal_story_3764191.utf8
#
# Unknown Event                                      1040916_bengal_story_3764765.utf8
#
# Unknown Event                                      1040917_bengal_index.utf8
#
# Unknown Event                                      1040917_bengal_story_3766311.utf8
#
# Unknown Event                                      1040917_bengal_story_3768886.utf8
#
# Unknown Event                                      1040917_bengal_story_3768887.utf8
#
# Unknown Event                                      1040917_bengal_story_3768888.utf8
#
# Unknown Event                                      1040917_bengal_story_3769066.utf8
#
# Unknown Event                                      1040918_bengal_index.utf8
#
# Unknown Event                                      1040918_bengal_story_3773127.utf8
#
# Unknown Event                                      1040918_bengal_story_3773128.utf8
#
# Unknown Event                                      1040918_bengal_story_3773130.utf8
#
# Unknown Event                                      1040918_bengal_story_3773132.utf8
#
# Unknown Event                                      1040918_bengal_story_3773133.utf8
#
# Unknown Event                                      1040918_bengal_story_3773134.utf8
#
# Unknown Event                                      1040919_bengal_index.utf8
#
# Unknown Event                                      1040919_bengal_story_3771066.utf8
#
# Unknown Event                                      1040919_bengal_story_3774487.utf8
#
# Unknown Event                                      1040919_bengal_story_3774613.utf8
#
# Unknown Event                                      1040919_bengal_story_3774678.utf8
#
# Unknown Event                                      1040919_bengal_story_3774865.utf8
#
# Unknown Event                                      1040919_bengal_story_3775192.utf8
#
# Unknown Event                                      1040919_bengal_story_3775345.utf8
#
# Unknown Event                                      1040919_bengal_story_3776560.utf8
#
# Unknown Event                                      1040919_bengal_story_3776561.utf8
#
# Unknown Event                                      1040919_bengal_story_3776562.utf8
#
# Unknown Event                                      1040919_bengal_story_3776563.utf8
#
# Unknown Event                                      1040919_bengal_story_3776564.utf8
#
# Unknown Event                                      1040919_bengal_story_3776565.utf8
#
# Unknown Event                                      1040919_bengal_story_3776566.utf8
#
# Unknown Event                                      1040919_bengal_story_3776567.utf8
#
# Unknown Event                                      1040919_bengal_story_3777205.utf8
#
# Unknown Event                                      1040920_bengal_index.utf8
#
# Unknown Event                                      1040920_bengal_story_3779564.utf8
#
# Unknown Event                                      1040920_bengal_story_3779565.utf8
#
# Unknown Event                                      1040920_bengal_story_3779566.utf8
#
# Unknown Event                                      1040920_bengal_story_3779567.utf8
#
# Unknown Event                                      1040920_bengal_story_3779568.utf8
#
# Unknown Event                                      1040920_bengal_story_3779570.utf8
#
# Unknown Event                                      1040921_bengal_index.utf8
#
# Unknown Event                                      1040921_bengal_story_3783916.utf8
#
# Unknown Event                                      1040921_bengal_story_3783917.utf8
#
# Unknown Event                                      1040921_bengal_story_3783918.utf8
#
# Unknown Event                                      1040921_bengal_story_3783919.utf8
#
# Unknown Event                                      1040921_bengal_story_3783920.utf8
#
# Bombing/Explosion                                  1040921_bengal_story_3783922.utf8
#
# Unknown Event                                      1040921_bengal_story_3783923.utf8
#
# Unknown Event                                      1040921_bengal_story_3783924.utf8
#
# Unknown Event                                      1040922_bengal_index.utf8
#
# Unknown Event                                      1040922_bengal_story_3788155.utf8
#
# Unknown Event                                      1040922_bengal_story_3788156.utf8
#
# Unknown Event                                      1040922_bengal_story_3788157.utf8
#
# Unknown Event                                      1040922_bengal_story_3788158.utf8
#
# Unknown Event                                      1040922_bengal_story_3788159.utf8
#
# Unknown Event                                      1040922_bengal_story_3788160.utf8
#
# Unknown Event                                      1040922_bengal_story_3788638.utf8
#
# Unknown Event                                      1040923_bengal_index.utf8
#
# Unknown Event                                      1040923_bengal_story_3793197.utf8
#
# Bombing/Explosion                                  1040923_bengal_story_3793198.utf8
#
# Unknown Event                                      1040923_bengal_story_3793202.utf8
#
# Unknown Event                                      1040923_bengal_story_3793203.utf8
#
# Unknown Event                                      1040923_bengal_story_3793204.utf8
#
# Unknown Event                                      1040923_bengal_story_3793205.utf8
#
# Unknown Event                                      1040923_bengal_story_3793206.utf8
#
# Unknown Event                                      1040923_bengal_story_3793207.utf8
#
# Unknown Event                                      1040923_bengal_story_3793799.utf8
#
# Unknown Event                                      1040924_bengal_index.utf8
#
# Unknown Event                                      1040924_bengal_story_3797457.utf8
#
# Unknown Event                                      1040924_bengal_story_3797460.utf8
#
# Unknown Event                                      1040924_bengal_story_3797461.utf8
#
# Unknown Event                                      1040924_bengal_story_3797462.utf8
#
# Unknown Event                                      1040924_bengal_story_3797463.utf8
#
# Unknown Event                                      1040924_bengal_story_3797685.utf8
#
# Unknown Event                                      1040925_bengal_index.utf8
#
# Unknown Event                                      1040925_bengal_story_3801697.utf8
#
# Unknown Event                                      1040925_bengal_story_3801698.utf8
#
# Unknown Event                                      1040925_bengal_story_3801699.utf8
#
# Unknown Event                                      1040925_bengal_story_3801700.utf8
#
# Unknown Event                                      1040925_bengal_story_3801728.utf8
#
# Unknown Event                                      1040926_bengal_index.utf8
#
# Unknown Event                                      1040926_bengal_story_3805209.utf8
#
# Unknown Event                                      1040926_bengal_story_3805210.utf8
#
# Unknown Event                                      1040926_bengal_story_3805212.utf8
#
# Unknown Event                                      1040926_bengal_story_3805213.utf8
#
# Unknown Event                                      1040926_bengal_story_3805214.utf8
#
# Unknown Event                                      1040926_bengal_story_3805317.utf8
#
# Unknown Event                                      1040926_bengal_story_3805318.utf8
#
# Unknown Event                                      1040926_bengal_story_3805319.utf8
#
# Unknown Event                                      1040926_bengal_story_3805320.utf8
#
# Unknown Event                                      1040926_bengal_story_3805321.utf8
#
# Unknown Event                                      1040926_bengal_story_3805322.utf8
#
# Unknown Event                                      1040927_bengal_index.utf8
#
# Unknown Event                                      1040927_bengal_story_3808850.utf8
#
# Unknown Event                                      1040927_bengal_story_3808851.utf8
#
# Unknown Event                                      1040927_bengal_story_3808852.utf8
#
# Unknown Event                                      1040927_bengal_story_3808853.utf8
#
# Unknown Event                                      1040927_bengal_story_3808854.utf8
#
# Unknown Event                                      1040927_bengal_story_3808907.utf8
#
# Unknown Event                                      1040928_bengal_index.utf8
#
# Unknown Event                                      1040928_bengal_story_3813331.utf8
#
# Unknown Event                                      1040928_bengal_story_3813332.utf8
#
# Unknown Event                                      1040928_bengal_story_3813333.utf8
#
# Unknown Event                                      1040928_bengal_story_3813334.utf8
#
# Unknown Event                                      1040928_bengal_story_3813337.utf8
#
# Unknown Event                                      1040928_bengal_story_3813364.utf8
#
# Unknown Event                                      1040929_bengal_index.utf8
#
# Unknown Event                                      1040929_bengal_story_3817829.utf8
#
# Unknown Event                                      1040929_bengal_story_3817830.utf8
#
# Unknown Event                                      1040929_bengal_story_3817831.utf8
#
# Unknown Event                                      1040929_bengal_story_3817832.utf8
#
# Unknown Event                                      1040929_bengal_story_3817910.utf8
#
# Unknown Event                                      1040930_bengal_index.utf8
#
# Unknown Event                                      1040930_bengal_story_3820691.utf8
#
# Unknown Event                                      1040930_bengal_story_3822033.utf8
#
# Unknown Event                                      1040930_bengal_story_3822034.utf8
#
# Unknown Event                                      1040930_bengal_story_3822035.utf8
#
# Unknown Event                                      1040930_bengal_story_3822036.utf8
#
# Unknown Event                                      1040930_bengal_story_3822037.utf8
#
# Unknown Event                                      1040930_bengal_story_3822038.utf8
#
# Unknown Event                                      1040930_bengal_story_3823349.utf8
#
# Unknown Event                                      1041001_bengal_index.utf8
#
# Unknown Event                                      1041001_bengal_story_3827228.utf8
#
# Unknown Event                                      1041001_bengal_story_3827229.utf8
#
# Unknown Event                                      1041001_bengal_story_3827230.utf8
#
# Unknown Event                                      1041001_bengal_story_3827231.utf8
#
# Unknown Event                                      1041001_bengal_story_3827232.utf8
#
# Unknown Event                                      1041001_bengal_story_3827233.utf8
#
# Unknown Event                                      1041001_bengal_story_3827234.utf8
#
# Unknown Event                                      1041002_bengal_index.utf8
#
# Unknown Event                                      1041002_bengal_story_3831784.utf8
#
# Unknown Event                                      1041002_bengal_story_3831785.utf8
#
# Unknown Event                                      1041002_bengal_story_3831786.utf8
#
# Unknown Event                                      1041002_bengal_story_3831787.utf8
#
# Unknown Event                                      1041002_bengal_story_3831788.utf8
#
# Unknown Event                                      1041003_bengal_index.utf8
#
# Unknown Event                                      1041003_bengal_story_3835179.utf8
#
# Unknown Event                                      1041003_bengal_story_3835181.utf8
#
# Unknown Event                                      1041003_bengal_story_3835182.utf8
#
# Unknown Event                                      1041003_bengal_story_3835183.utf8
#
# Unknown Event                                      1041003_bengal_story_3835184.utf8
#
# Unknown Event                                      1041003_bengal_story_3835185.utf8
#
# Unknown Event                                      1041003_bengal_story_3835262.utf8
#
# Unknown Event                                      1041003_bengal_story_3835263.utf8
#
# Unknown Event                                      1041003_bengal_story_3835264.utf8
#
# Unknown Event                                      1041003_bengal_story_3835265.utf8
#
# Armed Assault                                      1041003_bengal_story_3835266.utf8
#
# Unknown Event                                      1041003_bengal_story_3835267.utf8
#
# Unknown Event                                      1041003_bengal_story_3835268.utf8
#
# Unknown Event                                      1041003_bengal_story_3835847.utf8
#
# Unknown Event                                      1041004_bengal_index.utf8
#
# Unknown Event                                      1041004_bengal_story_3838517.utf8
#
# Unknown Event                                      1041004_bengal_story_3838518.utf8
#
# Unknown Event                                      1041004_bengal_story_3838519.utf8
#
# Unknown Event                                      1041004_bengal_story_3838520.utf8
#
# Unknown Event                                      1041004_bengal_story_3838521.utf8
#
# Unknown Event                                      1041004_bengal_story_3838522.utf8
#
# Unknown Event                                      1041004_bengal_story_3838523.utf8
#
# Bombing/Explosion                                  1041005_bengal_index.utf8
#
# Unknown Event                                      1041005_bengal_story_3843012.utf8
#
# Bombing/Explosion                                  1041005_bengal_story_3843013.utf8
#
# Unknown Event                                      1041005_bengal_story_3843014.utf8
#
# Unknown Event                                      1041005_bengal_story_3843015.utf8
#
# Unknown Event                                      1041005_bengal_story_3843016.utf8
#
# Unknown Event                                      1041005_bengal_story_3843017.utf8
#
# Unknown Event                                      1041006_bengal_index.utf8
#
# Unknown Event                                      1041006_bengal_story_3847614.utf8
#
# Unknown Event                                      1041006_bengal_story_3847615.utf8
#
# Unknown Event                                      1041006_bengal_story_3847616.utf8
#
# Unknown Event                                      1041006_bengal_story_3847617.utf8
#
# Unknown Event                                      1041006_bengal_story_3847618.utf8
#
# Unknown Event                                      1041006_bengal_story_3847619.utf8
#
# Unknown Event                                      1041006_bengal_story_3847709.utf8
#
# Unknown Event                                      1041007_bengal_index.utf8
#
# Unknown Event                                      1041007_bengal_story_3851622.utf8
#
# Unknown Event                                      1041007_bengal_story_3851694.utf8
#
# Unknown Event                                      1041007_bengal_story_3851696.utf8
#
# Unknown Event                                      1041007_bengal_story_3851699.utf8
#
# Unknown Event                                      1041007_bengal_story_3851700.utf8
#
# Bombing/Explosion                                  1041007_bengal_story_3851701.utf8
#
# Unknown Event                                      1041007_bengal_story_3852237.utf8
#
# Unknown Event                                      1041008_bengal_index.utf8
#
# Unknown Event                                      1041008_bengal_story_3857018.utf8
#
# Unknown Event                                      1041008_bengal_story_3857020.utf8
#
# Unknown Event                                      1041008_bengal_story_3857021.utf8
#
# Unknown Event                                      1041008_bengal_story_3857022.utf8
#
# Unknown Event                                      1041009_bengal_index.utf8
#
# Unknown Event                                      1041009_bengal_story_3860757.utf8
#
# Unknown Event                                      1041009_bengal_story_3860758.utf8
#
# Unknown Event                                      1041010_bengal_index.utf8
#
# Unknown Event                                      1041010_bengal_story_3862360.utf8
#
# Unknown Event                                      1041010_bengal_story_3862737.utf8
#
# Unknown Event                                      1041010_bengal_story_3862783.utf8
#
# Unknown Event                                      1041010_bengal_story_3862837.utf8
#
# Unknown Event                                      1041010_bengal_story_3862991.utf8
#
# Unknown Event                                      1041010_bengal_story_3863260.utf8
#
# Unknown Event                                      1041010_bengal_story_3863642.utf8
#
# Unknown Event                                      1041010_bengal_story_3864208.utf8
#
# Unknown Event                                      1041010_bengal_story_3864209.utf8
#
# Unknown Event                                      1041010_bengal_story_3864210.utf8
#
# Unknown Event                                      1041010_bengal_story_3864211.utf8
#
# Unknown Event                                      1041011_bengal_index.utf8
#
# Unknown Event                                      1041011_bengal_story_3867929.utf8
#
# Unknown Event                                      1041011_bengal_story_3867930.utf8
#
# Unknown Event                                      1041011_bengal_story_3867931.utf8
#
# Unknown Event                                      1041011_bengal_story_3867932.utf8
#
# Unknown Event                                      1041011_bengal_story_3867934.utf8
#
# Unknown Event                                      1041011_bengal_story_3868133.utf8
#
# Unknown Event                                      1041012_bengal_index.utf8
#
# Unknown Event                                      1041012_bengal_story_3872462.utf8
#
# Unknown Event                                      1041012_bengal_story_3872463.utf8
#
# Unknown Event                                      1041012_bengal_story_3872464.utf8
#
# Unknown Event                                      1041012_bengal_story_3872465.utf8
#
# Unknown Event                                      1041013_bengal_index.utf8
#
# Unknown Event                                      1041013_bengal_story_3876370.utf8
#
# Unknown Event                                      1041013_bengal_story_3876371.utf8
#
# Unknown Event                                      1041013_bengal_story_3876372.utf8
#
# Unknown Event                                      1041013_bengal_story_3876767.utf8
#
# Unknown Event                                      1041014_bengal_index.utf8
#
# Unknown Event                                      1041014_bengal_story_3880716.utf8
#
# Unknown Event                                      1041014_bengal_story_3880717.utf8
#
# Unknown Event                                      1041014_bengal_story_3880718.utf8
#
# Unknown Event                                      1041014_bengal_story_3880719.utf8
#
# Unknown Event                                      1041014_bengal_story_3880720.utf8
#
# Unknown Event                                      1041014_bengal_story_3880721.utf8
#
# Unknown Event                                      1041014_bengal_story_3881318.utf8
#
# Unknown Event                                      1041015_bengal_index.utf8
#
# Unknown Event                                      1041015_bengal_story_3885658.utf8
#
# Unknown Event                                      1041015_bengal_story_3885659.utf8
#
# Unknown Event                                      1041015_bengal_story_3885661.utf8
#
# Unknown Event                                      1041015_bengal_story_3885746.utf8
#
# Unknown Event                                      1041015_bengal_story_3886047.utf8
#
# Unknown Event                                      1041016_bengal_index.utf8
#
# Unknown Event                                      1041016_bengal_story_3889765.utf8
#
# Unknown Event                                      1041016_bengal_story_3889766.utf8
#
# Unknown Event                                      1041016_bengal_story_3889767.utf8
#
# Unknown Event                                      1041017_bengal_index.utf8
#
# Unknown Event                                      1041017_bengal_story_3893485.utf8
#
# Unknown Event                                      1041017_bengal_story_3893486.utf8
#
# Unknown Event                                      1041017_bengal_story_3893488.utf8
#
# Unknown Event                                      1041017_bengal_story_3893489.utf8
#
# Unknown Event                                      1041017_bengal_story_3893490.utf8
#
# Unknown Event                                      1041018_bengal_index.utf8
#
# Unknown Event                                      1041018_bengal_story_3896646.utf8
#
# Armed Assault                                      1041018_bengal_story_3896647.utf8
#
# Unknown Event                                      1041018_bengal_story_3896648.utf8
#
# Unknown Event                                      1041018_bengal_story_3896649.utf8
#
# Unknown Event                                      1041018_bengal_story_3896650.utf8
#
# Unknown Event                                      1041019_bengal_index.utf8
#
# Unknown Event                                      1041019_bengal_story_3900607.utf8
#
# Unknown Event                                      1041019_bengal_story_3900608.utf8
#
# Unknown Event                                      1041019_bengal_story_3900609.utf8
#
# Unknown Event                                      1041019_bengal_story_3900610.utf8
#
# Unknown Event                                      1041019_bengal_story_3900611.utf8
#
# Unknown Event                                      1041020_bengal_index.utf8
#
# Unknown Event                                      1041020_bengal_story_3904993.utf8
#
# Unknown Event                                      1041021_bengal_index.utf8
#
# Unknown Event                                      1041021_bengal_story_3909448.utf8
#
# Unknown Event                                      1041021_bengal_story_3909449.utf8
#
# Unknown Event                                      1041021_bengal_story_3909450.utf8
#
# Unknown Event                                      1041021_bengal_story_3909451.utf8
#
# Armed Assault                                      1041021_bengal_story_3909688.utf8
#
# Unknown Event                                      1041022_bengal_index.utf8
#
# Hostage                                            1041022_bengal_story_3913501.utf8
#
# Unknown Event                                      1041022_bengal_story_3913502.utf8
#
# Unknown Event                                      1041022_bengal_story_3913503.utf8
#
# Unknown Event                                      1041022_bengal_story_3913504.utf8
#
# Unknown Event                                      1041022_bengal_story_3913505.utf8
#
# Unknown Event                                      1041022_bengal_story_3913506.utf8
#
# Unknown Event                                      1041022_bengal_story_3913655.utf8
#
# Unknown Event                                      1041023_bengal_index.utf8
#
# Unknown Event                                      1041023_bengal_story_3917109.utf8
#
# Unknown Event                                      1041023_bengal_story_3917110.utf8
#
# Unknown Event                                      1041023_bengal_story_3917111.utf8
#
# Unknown Event                                      1041023_bengal_story_3917112.utf8
#
# Unknown Event                                      1041025_bengal_index.utf8
#
# Unknown Event                                      1041025_bengal_story_3921668.utf8
#
# Unknown Event                                      1041025_bengal_story_3921669.utf8
#
# Unknown Event                                      1041025_bengal_story_3921670.utf8
#
# Facility/Infrastructure Attack                     1041025_bengal_story_3921671.utf8
#
# Unknown Event                                      1041025_bengal_story_3921673.utf8
#
# Unknown Event                                      1041025_bengal_story_3921894.utf8
#
# Unknown Event                                      1041026_bengal_index.utf8
#
# Unknown Event                                      1041026_bengal_story_3925843.utf8
#
# Unknown Event                                      1041026_bengal_story_3925844.utf8
#
# Unknown Event                                      1041026_bengal_story_3925845.utf8
#
# Unknown Event                                      1041026_bengal_story_3925846.utf8
#
# Unknown Event                                      1041026_bengal_story_3925847.utf8
#
# Facility/Infrastructure Attack                     1041026_bengal_story_3926030.utf8
#
# Unknown Event                                      1041027_bengal_index.utf8
#
# Unknown Event                                      1041027_bengal_story_3930540.utf8
#
# Unknown Event                                      1041027_bengal_story_3930541.utf8
#
# Unknown Event                                      1041027_bengal_story_3930542.utf8
#
# Unknown Event                                      1041027_bengal_story_3930543.utf8
#
# Unknown Event                                      1041027_bengal_story_3930545.utf8
#
# Unknown Event                                      1041027_bengal_story_3930546.utf8
#
# Unknown Event                                      1041028_bengal_index.utf8
#
# Unknown Event                                      1041028_bengal_story_3934779.utf8
#
# Unknown Event                                      1041028_bengal_story_3934780.utf8
#
# Unknown Event                                      1041028_bengal_story_3934781.utf8
#
# Unknown Event                                      1041028_bengal_story_3934782.utf8
#
# Unknown Event                                      1041028_bengal_story_3934783.utf8
#
# Armed Assault                                      1041028_bengal_story_3934784.utf8
#
# Assassination                                      1041028_bengal_story_3935070.utf8
#
# Unknown Event                                      1041029_bengal_index.utf8
#
# Unknown Event                                      1041029_bengal_story_3939224.utf8
#
# Unknown Event                                      1041029_bengal_story_3939225.utf8
#
# Unknown Event                                      1041029_bengal_story_3939226.utf8
#
# Unknown Event                                      1041029_bengal_story_3939227.utf8
#
# Unknown Event                                      1041029_bengal_story_3939293.utf8
#
# Unknown Event                                      1041030_bengal_index.utf8
#
# Unknown Event                                      1041030_bengal_story_3943447.utf8
#
# Unknown Event                                      1041030_bengal_story_3943683.utf8
#
# Unknown Event                                      1041030_bengal_story_3943684.utf8
#
# Unknown Event                                      1041030_bengal_story_3943686.utf8
#
# Unknown Event                                      1041030_bengal_story_3943899.utf8
#
# Unknown Event                                      1041031_bengal_index.utf8
#
# Unknown Event                                      1041031_bengal_story_3947375.utf8
#
# Unknown Event                                      1041031_bengal_story_3947377.utf8
#
# Unknown Event                                      1041031_bengal_story_3947378.utf8
#
# Unknown Event                                      1041031_bengal_story_3947379.utf8
#
# Unknown Event                                      1041031_bengal_story_3947454.utf8
#
# Unknown Event                                      1041031_bengal_story_3947456.utf8
#
# Unknown Event                                      1041031_bengal_story_3947457.utf8
#
# Unknown Event                                      1041031_bengal_story_3947458.utf8
#
# Unknown Event                                      1041101_bengal_index.utf8
#
# Unknown Event                                      1041101_bengal_story_3950834.utf8
#
# Unknown Event                                      1041101_bengal_story_3950835.utf8
#
# Unknown Event                                      1041101_bengal_story_3950836.utf8
#
# Unknown Event                                      1041101_bengal_story_3950837.utf8
#
# Unknown Event                                      1041101_bengal_story_3950838.utf8
#
# Unknown Event                                      1041101_bengal_story_3950839.utf8
#
# Unknown Event                                      1041102_bengal_index.utf8
#
# Unknown Event                                      1041102_bengal_story_3955214.utf8
#
# Unknown Event                                      1041102_bengal_story_3955215.utf8
#
# Unknown Event                                      1041102_bengal_story_3955216.utf8
#
# Unknown Event                                      1041102_bengal_story_3955217.utf8
#
# Unknown Event                                      1041102_bengal_story_3955218.utf8
#
# Unknown Event                                      1041102_bengal_story_3955219.utf8
#
# Unknown Event                                      1041102_bengal_story_3955950.utf8
#
# Unknown Event                                      1041103_bengal_index.utf8
#
# Unknown Event                                      1041103_bengal_story_3959282.utf8
#
# Unknown Event                                      1041103_bengal_story_3959283.utf8
#
# Unknown Event                                      1041103_bengal_story_3959284.utf8
#
# Unknown Event                                      1041103_bengal_story_3959285.utf8
#
# Unknown Event                                      1041103_bengal_story_3959286.utf8
#
# Unknown Event                                      1041103_bengal_story_3960095.utf8
#
# Unknown Event                                      1041104_bengal_index.utf8
#
# Unknown Event                                      1041104_bengal_story_3963590.utf8
#
# Unknown Event                                      1041104_bengal_story_3963591.utf8
#
# Unknown Event                                      1041104_bengal_story_3963592.utf8
#
# Unknown Event                                      1041104_bengal_story_3963698.utf8
#
# Unknown Event                                      1041105_bengal_index.utf8
#
# Unknown Event                                      1041106_bengal_index.utf8
#
# ...
#
# Unknown Event                                      1041208_bengal_story_4100927.utf8
#
# Unknown Event                                      1041208_bengal_story_4100928.utf8
#
# Unknown Event                                      1041208_bengal_story_4100929.utf8
#
# Unknown Event                                      1041208_bengal_story_4100930.utf8
#
# Unknown Event                                      1041208_bengal_story_4100932.utf8
#
# Unknown Event                                      1041208_bengal_story_4101251.utf8
#
# Unknown Event                                      1041209_bengal_index.utf8
#
# Unknown Event                                      1041209_bengal_story_4105674.utf8
#
# Unknown Event                                      1041209_bengal_story_4105675.utf8
#
# Unknown Event                                      1041209_bengal_story_4105676.utf8
#
# Unknown Event                                      1041209_bengal_story_4105677.utf8
#
# Unknown Event                                      1041209_bengal_story_4105678.utf8
#
# Unknown Event                                      1041209_bengal_story_4105679.utf8
#
# Unknown Event                                      1041209_bengal_story_4106028.utf8
#
# Unknown Event                                      1041210_bengal_index.utf8
#
# Unknown Event                                      1041210_bengal_story_4110233.utf8
#
# Unknown Event                                      1041210_bengal_story_4110234.utf8
#
# Unknown Event                                      1041210_bengal_story_4110235.utf8
#
# Bombing/Explosion                                  1041210_bengal_story_4110236.utf8
#
# Unknown Event                                      1041210_bengal_story_4110237.utf8
#
# Armed Assault                                      1041210_bengal_story_4110688.utf8
#
# Unknown Event                                      1041211_bengal_index.utf8
#
# Unknown Event                                      1041211_bengal_story_4115147.utf8
#
# Unknown Event                                      1041211_bengal_story_4115148.utf8
#
# Unknown Event                                      1041211_bengal_story_4115149.utf8
#
# Unknown Event                                      1041211_bengal_story_4115150.utf8
#
# Unknown Event                                      1041211_bengal_story_4115152.utf8
#
# Unknown Event                                      1041212_bengal_index.utf8
#
# Unknown Event                                      1041212_bengal_story_4118982.utf8
#
# Unknown Event                                      1041212_bengal_story_4118983.utf8
#
# Unknown Event                                      1041212_bengal_story_4118984.utf8
#
# Unknown Event                                      1041212_bengal_story_4118985.utf8
#
# Unknown Event                                      1041212_bengal_story_4118986.utf8
#
# Unknown Event                                      1041212_bengal_story_4118987.utf8
#
# Unknown Event                                      1041212_bengal_story_4118988.utf8
#
# Unknown Event                                      1041213_bengal_index.utf8
#
# Unknown Event                                      1041213_bengal_story_4122186.utf8
#
# Unknown Event                                      1041213_bengal_story_4122187.utf8
#
# Facility/Infrastructure Attack                     1041213_bengal_story_4122189.utf8
#
# Unknown Event                                      1041213_bengal_story_4122190.utf8
#
# Unknown Event                                      1041213_bengal_story_4122192.utf8
#
# Unknown Event                                      1041214_bengal_index.utf8
#
# Unknown Event                                      1041214_bengal_story_4126056.utf8
#
# Unknown Event                                      1041214_bengal_story_4126058.utf8
#
# Unknown Event                                      1041214_bengal_story_4126059.utf8
#
# Unknown Event                                      1041214_bengal_story_4126060.utf8
#
# Unknown Event                                      1041214_bengal_story_4126061.utf8
#
# Unknown Event                                      1041214_bengal_story_4126063.utf8
#
# Unknown Event                                      1041215_bengal_index.utf8
#
# Unknown Event                                      1041215_bengal_story_4130486.utf8
#
# Unknown Event                                      1041215_bengal_story_4130487.utf8
#
# Unknown Event                                      1041215_bengal_story_4130490.utf8
#
# Unknown Event                                      1041215_bengal_story_4130491.utf8
#
# Unknown Event                                      1041215_bengal_story_4130492.utf8
#
# Unknown Event                                      1041215_bengal_story_4130769.utf8
#
# Unknown Event                                      1041216_bengal_index.utf8
#
# Unknown Event                                      1041216_bengal_story_4134892.utf8
#
# Unknown Event                                      1041216_bengal_story_4134893.utf8
#
# Unknown Event                                      1041216_bengal_story_4134894.utf8
#
# Unknown Event                                      1041216_bengal_story_4134895.utf8
#
# Facility/Infrastructure Attack                     1041216_bengal_story_4135530.utf8
#
# Unknown Event                                      1041217_bengal_index.utf8
#
# Unknown Event                                      1041217_bengal_story_4139810.utf8
#
# Unknown Event                                      1041217_bengal_story_4139811.utf8
#
# Unknown Event                                      1041217_bengal_story_4139812.utf8
#
# Unknown Event                                      1041217_bengal_story_4140051.utf8
#
# Unknown Event                                      1041218_bengal_index.utf8
#
# Unknown Event                                      1041218_bengal_story_4144684.utf8
#
# Unknown Event                                      1041218_bengal_story_4144685.utf8
#
# Unknown Event                                      1041218_bengal_story_4144686.utf8
#
# Unknown Event                                      1041218_bengal_story_4144687.utf8
#
# Unknown Event                                      1041218_bengal_story_4144688.utf8
#
# Unknown Event                                      1041218_bengal_story_4144723.utf8
#
# Unknown Event                                      1041219_bengal_index.utf8
#
# Unknown Event                                      1041219_bengal_story_4147969.utf8
#
# Unarmed Assault                                    1041219_bengal_story_4147970.utf8
#
# Unknown Event                                      1041219_bengal_story_4147971.utf8
#
# Unknown Event                                      1041219_bengal_story_4147972.utf8
#
# Unknown Event                                      1041219_bengal_story_4147973.utf8
#
# Unknown Event                                      1041219_bengal_story_4147974.utf8
#
# Unknown Event                                      1041219_bengal_story_4148009.utf8
#
# Hostage                                            1041219_bengal_story_4148011.utf8
#
# Unknown Event                                      1041219_bengal_story_4148012.utf8
#
# Unknown Event                                      1041219_bengal_story_4148013.utf8
#
# Unknown Event                                      1041219_bengal_story_4148014.utf8
#
# Unknown Event                                      1041219_bengal_story_4148015.utf8
#
# Unknown Event                                      1041219_bengal_story_4148016.utf8
#
# Unknown Event                                      1041219_bengal_story_4148051.utf8
#
# Unknown Event                                      1041220_bengal_index.utf8
#
# Unknown Event                                      1041220_bengal_story_4151101.utf8
#
# Unknown Event                                      1041220_bengal_story_4151102.utf8
#
# Unknown Event                                      1041220_bengal_story_4151103.utf8
#
# Unknown Event                                      1041220_bengal_story_4151104.utf8
#
# Unknown Event                                      1041220_bengal_story_4151105.utf8
#
# Unknown Event                                      1041220_bengal_story_4151106.utf8
#
# Unknown Event                                      1041221_bengal_index.utf8
#
# Unknown Event                                      1041221_bengal_story_4155198.utf8
#
# Unknown Event                                      1041221_bengal_story_4155199.utf8
#
# Facility/Infrastructure Attack                     1041221_bengal_story_4155200.utf8
#
# Unknown Event                                      1041221_bengal_story_4155202.utf8
#
# Unknown Event                                      1041221_bengal_story_4155203.utf8
#
# Unknown Event                                      1041221_bengal_story_4155204.utf8
#
# Bombing/Explosion                                  1041221_bengal_story_4155363.utf8
#
# Unknown Event                                      1041222_bengal_index.utf8
#
# Unknown Event                                      1041222_bengal_story_4159450.utf8
#
# Unknown Event                                      1041222_bengal_story_4159451.utf8
#
# Unknown Event                                      1041222_bengal_story_4159452.utf8
#
# Unknown Event                                      1041222_bengal_story_4159453.utf8
#
# Unknown Event                                      1041222_bengal_story_4159781.utf8
#
# Unknown Event                                      1041223_bengal_index.utf8
#
# Unknown Event                                      1041223_bengal_story_4164765.utf8
#
# Unknown Event                                      1041223_bengal_story_4164766.utf8
#
# Unknown Event                                      1041223_bengal_story_4164767.utf8
#
# Unknown Event                                      1041223_bengal_story_4164768.utf8
#
# Unknown Event                                      1041223_bengal_story_4164769.utf8
#
# Unknown Event                                      1041223_bengal_story_4164770.utf8
#
# Unarmed Assault                                    1041223_bengal_story_4164771.utf8
#
# Unknown Event                                      1041223_bengal_story_4164772.utf8
#
# Unknown Event                                      1041223_bengal_story_4164773.utf8
#
# Hostage                                            1041224_bengal_index.utf8
#
# Hostage                                            1041224_bengal_story_4168757.utf8
#
# Unknown Event                                      1041224_bengal_story_4169250.utf8
#
# Unknown Event                                      1041224_bengal_story_4169251.utf8
#
# Unknown Event                                      1041224_bengal_story_4169252.utf8
#
# Unknown Event                                      1041224_bengal_story_4169253.utf8
#
# Unknown Event                                      1041224_bengal_story_4169254.utf8
#
# Unknown Event                                      1041224_bengal_story_4169255.utf8
#
# Unknown Event                                      1041225_bengal_index.utf8
#
# Unknown Event                                      1041225_bengal_story_4173122.utf8
#
# Unknown Event                                      1041225_bengal_story_4173123.utf8
#
# Unknown Event                                      1041225_bengal_story_4173124.utf8
#
# Unknown Event                                      1041225_bengal_story_4173125.utf8
#
# Unknown Event                                      1041225_bengal_story_4173126.utf8
#
# Unknown Event                                      1041225_bengal_story_4173332.utf8
#
# Unknown Event                                      1041226_bengal_index.utf8
#
# Unknown Event                                      1041226_bengal_story_4176098.utf8
#
# Unknown Event                                      1041226_bengal_story_4176099.utf8
#
# Unknown Event                                      1041226_bengal_story_4176100.utf8
#
# Unknown Event                                      1041226_bengal_story_4176101.utf8
#
# Unknown Event                                      1041226_bengal_story_4176102.utf8
#
# Unknown Event                                      1041226_bengal_story_4176103.utf8
#
# Unknown Event                                      1041226_bengal_story_4176104.utf8
#
# Unknown Event                                      1041226_bengal_story_4176105.utf8
#
# Unknown Event                                      1041226_bengal_story_4176248.utf8
#
# Unknown Event                                      1041226_bengal_story_4176249.utf8
#
# Unknown Event                                      1041226_bengal_story_4176250.utf8
#
# Unknown Event                                      1041226_bengal_story_4176251.utf8
#
# Unknown Event                                      1041226_bengal_story_4176252.utf8
#
# Unknown Event                                      1041226_bengal_story_4176253.utf8
#
# Unknown Event                                      1041226_bengal_story_4176254.utf8
#
# Armed Assault                                      1041226_bengal_story_4176722.utf8
#
# Unknown Event                                      1041227_bengal_index.utf8
#
# Unknown Event                                      1041227_bengal_story_4179294.utf8
#
# Unknown Event                                      1041227_bengal_story_4179295.utf8
#
# Unknown Event                                      1041227_bengal_story_4179296.utf8
#
# Unknown Event                                      1041227_bengal_story_4179297.utf8
#
# Unknown Event                                      1041227_bengal_story_4179298.utf8
#
# Unknown Event                                      1041227_bengal_story_4179299.utf8
#
# Unknown Event                                      1041227_bengal_story_4179347.utf8
#
# Unknown Event                                      1041228_bengal_index.utf8
#
# Unknown Event                                      1041228_bengal_story_4183711.utf8
#
# Unknown Event                                      1041228_bengal_story_4183712.utf8
#
# Unknown Event                                      1041228_bengal_story_4183713.utf8
#
# Unknown Event                                      1041228_bengal_story_4183714.utf8
#
# Unknown Event                                      1041228_bengal_story_4183715.utf8
#
# Unknown Event                                      1041228_bengal_story_4183716.utf8
#
# Unknown Event                                      1041228_bengal_story_4183717.utf8
#
# Unknown Event                                      1041228_bengal_story_4183718.utf8
#
# Unknown Event                                      1041229_bengal_index.utf8
#
# Unknown Event                                      1041229_bengal_story_4187824.utf8
#
# Unknown Event                                      1041229_bengal_story_4187825.utf8
#
# Unknown Event                                      1041229_bengal_story_4187826.utf8
#
# Unknown Event                                      1041229_bengal_story_4187828.utf8
#
# Unknown Event                                      1041229_bengal_story_4187829.utf8
#
# Unknown Event                                      1041230_bengal_index.utf8
#
# Unknown Event                                      1041230_bengal_story_4191788.utf8
#
# Unknown Event                                      1041230_bengal_story_4191789.utf8
#
# Unknown Event                                      1041230_bengal_story_4191790.utf8
#
# Unknown Event                                      1041230_bengal_story_4191791.utf8
#
# Armed Assault                                      1041230_bengal_story_4191861.utf8
#
# Unknown Event                                      1041231_bengal_index.utf8
#
# Armed Assault                                      1041231_bengal_story_4194933.utf8
#
# Unknown Event                                      1041231_bengal_story_4194934.utf8
#
# Unknown Event                                      1041231_bengal_story_4194935.utf8
#
# Unknown Event                                      1041231_bengal_story_4194936.utf8
#
# Unknown Event                                      1041231_bengal_story_4195522.utf8
#
# Unknown Event                                      1040901_business_index.utf8
#
# Unknown Event                                      1040901_business_story_3700171.utf8

# %%
for i in range(len(events_firedataset)):
  with open (INTERMEDIATE_FILES_PATH+'/firedataset_results.txt', 'a') as file_i:
    file_i.write(f'{events_firedataset[i]:50} {firedataset_filename_list[i]}\n')
